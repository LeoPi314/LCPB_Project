# %% [markdown]
# <center><h1><b>LET'S FIND $D^0$ DECAYS</b></h1></center>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import awkward as ak
import uproot

from itertools import combinations
import os

# %% [markdown]
# ---

# %% [markdown]
# # ACCESSING DATA

# %%
! ls /mnt/SingleTrackTrees/Data/alice_data_2023_LHC23f_535087_apass4_1300_Thinner/Output/Run535087
# Out:
# Chunk0950  Chunk1020  Chunk1050  Chunk1120  Chunk1150  Chunk1220
# Chunk1000  Chunk1030  Chunk1100  Chunk1130  Chunk1200  Chunk1300
# Chunk1010  Chunk1040  Chunk1110  Chunk1140  Chunk1210

# %%
! ls -lh /mnt/SingleTrackTrees/Data/alice_data_2023_LHC23f_535087_apass4_1300_Thinner/Output/Run535087/Chunk0950/001_007
# Out:
# total 2.0G
# -rwxr-xr-x 1 ubuntu ubuntu 2.0G May 21 08:38 AO2Dtree.root
# -rwxr-xr-x 1 ubuntu ubuntu  18K May 21 08:38 AnalysisResults.root
# -rwxr-xr-x 1 ubuntu ubuntu  518 May 21 08:38 input_data.txt

# %% [markdown]
# For now, we focus on the data of a single chunck of 2GB.

# %%
path = "/mnt/SingleTrackTrees/Data/alice_data_2023_LHC23f_535087_apass4_1300_Thinner/Output/Run535087/Chunk0950/001_007/AO2Dtree.root"
file = uproot.open(path)
file.classnames()
# Out:
# {'DF_2298181510431936;1': 'TDirectory',
#  'DF_2298181510431936/O2collision_001;1': 'TTree',
#  'DF_2298181510431936/O2filtertrack;1': 'TTree',
#  'DF_2298181510431936/O2filtertrackextr;1': 'TTree',
#  'DF_2298181510502944;1': 'TDirectory',
#  'DF_2298181510502944/O2collision_001;1': 'TTree',
#  'DF_2298181510502944/O2filtertrack;1': 'TTree',
#  'DF_2298181510502944/O2filtertrackextr;1': 'TTree',
#  'DF_2298181510571872;1': 'TDirectory',
#  'DF_2298181510571872/O2collision_001;1': 'TTree',
#  'DF_2298181510571872/O2filtertrack;1': 'TTree',
#  'DF_2298181510571872/O2filtertrackextr;1': 'TTree',
#  'DF_2298181510572384;1': 'TDirectory',
#  'DF_2298181510572384/O2collision_001;1': 'TTree',
#  'DF_2298181510572384/O2filtertrack;1': 'TTree',
#  'DF_2298181510572384/O2filtertrackextr;1': 'TTree',
#  'DF_2298181510642880;1': 'TDirectory',
#  'DF_2298181510642880/O2collision_001;1': 'TTree',
#  'DF_2298181510642880/O2filtertrack;1': 'TTree',
# ...

# %%
# # debug
# file["DF_2298181510431936/O2filtertrackextr"].show()

# %%
# debug
df_test = file["DF_2298181510431936/O2filtertrack"].arrays(library="pd")
df_test.tail(20)
# Out:
#        fIndexCollisions  fIsInsideBeamPipe  fTrackType        fX    fAlpha  \
# 66806             12539                  1           1  0.027249  2.873356
# 66807             12539                  1           1 -0.007118  2.082306
# 66808             12539                  1           1  0.035687 -1.793978
# 66809             12539                  1           1  0.045376 -2.627455
# 66810             12540                  1           1 -0.006714  1.971335
# 66811             12540                  1           1  0.013823  2.386948
# 66812             12540                  1           1 -0.040647  1.154443
# 66813             12540                  1           1 -0.048835  0.328047
# 66814             12541                  1           1  0.044518 -2.313488
# 66815             12541                  1           1  0.035573 -1.883195
# 66816             12541                  1           1  0.038057  3.114850
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## DATA INTO PANDAS DATAFRAME

# %%
# # CODE FOR UNIFYING EVERY ROOT FILE

# # let's build each path to every ROOT file:
# base = "/mnt/SingleTrackTrees/Data/alice_data_2023_LHC23f_535087_apass4_1300_Thinner/Output/Run535087"
# mid = ["Chunk0950/001_007", "Chunk1000/001_005", "Chunk1000/006_009", "Chunk1010/001_005", "Chunk1010/006_010"]  # ne mancano...
# final = "AO2Dtree.root"

# paths = []
# for mid_path in mid:
#     unified_path = os.path.join(base, mid_path, final)
#     paths.append( unified_path )
#     print( unified_path )

# %%
# debug
names_coll       = file.keys(filter_name=r"*O2collision_001")
print( len(names_coll) )   # numero di T-Directories nel file root aperto
# Out:
# 447

# %%
# # debug:
# names_coll       = file.keys(filter_name=r"*O2collision_001")
# values_coll = pd.concat( [ file[item].arrays(["fPosZ"], library="pd") for item in names_coll[0:20] ], ignore_index=True )
# values_coll

# %%
# # debug
# names_track      = file.keys(filter_name=r"*O2filtertrack")
# num=10
# values_track      = pd.concat( [ file[item]\
#     .arrays(["fIndexCollisions", "fAlpha"], library="pd") for item in names_track[0:num] ], ignore_index=True )
# fig,ax = plt.subplots(figsize=(13,3))
# y_val = values_track["fIndexCollisions"]
# plt.hist( y_val[ (y_val>-100) & (y_val<25) ] , bins=1000)
# plt.show()

# %% [markdown]
# Una giornata sprecata perchè ci sono indici di collisione negativi, dio santissimo il signore cristo.

# %%
# CODE FOR UNIFYING DIRECTORIES OF A SINGLE ROOT FILE from all three type of T-Trees:

# Load T-Trees from directories
names_track_extr = file.keys(filter_name=r"*O2filtertrackextr")
names_track      = file.keys(filter_name=r"*O2filtertrack")
names_coll       = file.keys(filter_name=r"*O2collision_001")
num = 30   # number of directories to unify
# if I try with all, it crashes, because in this notebook I'm doing the cuts only after loading all data (in order tp study the cuts)

list_of_df = []               # add the dataframes in a list (we will concat them later)

collision_offset = 0          # variable to correct the index of the collision (because it starts from 0 at each new TTree)

for i in range(num):          # cycle over directories (each with 3 TTrees)
    
    # Read collision tree
    df_coll = file[ names_coll[i] ].arrays(["fPosZ"], library="pd")   # I take the fPosZ column as a DataFrame             

    # Read track and trackextr
    df_trackextr = file[ names_track_extr[i] ].arrays(["fPt", "fEta", "fCharge", "fDcaXY",
         "fNsigmaTPCpi", "fNsigmaTPCka", "fNsigmaTPCpr", "fNsigmaTOFpi", "fNsigmaTOFka", "fNsigmaTOFpr"], library="pd" )
    df_track = file[ names_track[i] ].arrays(["fIndexCollisions", "fAlpha"], library="pd")
    # merging in a single dataframe
    df_trackextr["fIndexCollisions"] = df_track["fIndexCollisions"] 
    df_trackextr["fAlpha"] = df_track["fAlpha"]

    # we cut rows where the fIndexCollision is negative (for some reason)
    valid = df_track["fIndexCollisions"] >= 0
    df_track = df_track[valid].reset_index(drop=True)          
    df_trackextr = df_trackextr[valid].reset_index(drop=True)  

    
    # Now we for correct fPosZ (and add that column)
    df_trackextr["fPosZ"] = df_coll.iloc[df_trackextr["fIndexCollisions"].values]["fPosZ"].values
    df_trackextr["fIndexCollisions"] += collision_offset   # Fix local fIndexCollisions → global index
    list_of_df.append( df_trackextr )                  # add the dataframe in a list (we will concat them later)
    
    # Update offset for next loop
    collision_offset += len(df_coll)       


# Merge everything in the total dataframe
df = pd.concat(list_of_df, ignore_index=True)
N = len(df)

# %%
# debug
print("Final dataframe has", len(df), "rows")
memory = df.memory_usage(deep=True).sum() / (1024 ** 2)
print(f"The dataframe occupy {memory:.2f} MB")
df
# Out:
# Final dataframe has 2001183 rows
# The dataframe occupy 99.24 MB
#               fPt      fEta  fCharge    fDcaXY  fNsigmaTPCpi  fNsigmaTPCka  \
# 0        0.471111  0.086615       -1  0.004583      1.296971     -6.567831
# 1        0.537510  0.539420        1  0.011716      9.544146      1.979263
# 2        0.311392  0.052986        1 -0.005521     -1.248399    -12.175531
# 3        0.884602 -0.032689       -1 -0.001190      0.343225     -1.040863
# 4        0.371757 -0.593066       -1  0.003221     -1.047941     -8.668435
# ...           ...       ...      ...       ...           ...           ...
# 2001178  0.658030 -0.549699       -1  0.000182     -0.041799     -2.656244
# 2001179  0.302547  0.236509       -1 -0.010382      0.803188    -12.062794
# 2001180  0.556586  0.579686       -1  0.000255     -1.818171     -5.001888
# 2001181  0.662277 -0.338089       -1  0.003350     -0.616605     -3.442904
# 2001182  0.799283  0.581246       -1 -0.002887      0.222214     -0.635532
#
# ...

# %% [markdown]
# Ho fatto un check dettagliato se l'import nel giga dataframe avviene correttamente e mi pare di sì. Anche se tra un T-Tree e l'altro sembra saltare qualche numero in avanti del fIndex, non so per quale motivo, ma non è rilevante dato che l'importante è che gli indici di collisioni diverse rimangano diversi (e da controlli casuali risulta essere così).

# %%
# # OLD CODE FOR UNIFYING DIRECTORIES OF A SINGLE ROOT FILE:

# num = 10   # number of directories to unify 
# # if I try with all, it crashes, because in this notebook I'm doing the cuts only after loading all data (in order tp study the cuts)

# # Load T-Trees from directories
# names_track_extr = file.keys(filter_name=r"*O2filtertrackextr")
# names_track      = file.keys(filter_name=r"*O2filtertrack")
# names_coll       = file.keys(filter_name=r"*O2collision_001")

# # Read and concatenate all O2filtertrackextr T-Trees in a single dataframe
# values_track_extr = pd.concat( [ file[item]\
#     .arrays(["fPt","fEta","fCharge","fDcaXY","fNsigmaTPCpi","fNsigmaTPCka","fNsigmaTPCpr","fNsigmaTOFpi",
#              "fNsigmaTOFka","fNsigmaTOFpr" 	], library="pd") for item in names_track_extr[0:num] ], ignore_index=True )
# # Read and concatenate O2filtertrack T-Trees in a single dataframe (for "fIndexCollisions" and "fAlpha")
# values_track      = pd.concat( [ file[item]\
#     .arrays(["fIndexCollisions", "fAlpha"], library="pd") for item in names_track[0:num] ], ignore_index=True )

# # Add "fIndexCollisions" and "fAlpha" as a new columns
# values_track_extr["fIndexCollisions"] = values_track["fIndexCollisions"]
# values_track_extr["fAlpha"] = values_track["fAlpha"]

# # Read and concatenate O2collision_001 T-Trees in a single dataframe (for fPosZ)
# all_collisions = []
# for name in names_coll[0:num]:          # cycle over all the collision trees in all T-Directories
#     df_coll = file[name].arrays(["fPosZ"], library="pd")
#     all_collisions.append(df_coll)
# collision_df = pd.concat(all_collisions, ignore_index=True)   # dataframe with all fPosZ values

# # Add fPosZ to main DataFrame by matching fIndexCollisions
# # Note: fIndexCollisions points to rows in collision_df
# values_track_extr["fPosZ"] = collision_df.loc[ values_track_extr["fIndexCollisions"].values, "fPosZ"].values

# # Final result
# df = values_track_extr
# N = len(df)
# print('Original data:', N, 'rows')

# df

# %%
# # OLD CODE USED TO TAKE DATA FROM A SINGLE DIRECTORY OF A ROOT FILE:

# # all data from the Tree 'O2filtertrackextr' of one directory:
# df = file["DF_2298181510431936/O2filtertrackextr"].arrays(library="pd")

# # adding the column 'fIndexCollisions' from 'O2filtertrack':
# df_track = file["DF_2298181510431936/O2filtertrack"].arrays(["fIndexCollisions"], library="pd")
# df["fIndexCollisions"] = df_track["fIndexCollisions"]

# N = len(df)
# print('Original data:', N, 'rows')

# df

# %% [markdown]
# ---

# %% [markdown]
# # CUTS

# %% [markdown]
# ## PV (PRIMARY VERTEX)
# We reject $|fPosZ| > 10 \text{ cm}$ as requested (I don't know why).

# %%
tot_outside = len (df[ ( (df['fPosZ'] > 10) | (df['fPosZ'] < -10) ) ])
print("Number of rows with |fPosZ|<10:  ", N-tot_outside)
print("Number of rows with |fPosZ|>10:  ", tot_outside)
# Out:
# Number of rows with |fPosZ|<10:   1952597
# Number of rows with |fPosZ|>10:   48586

# %% [markdown]
# Almost all the values (97.5%) have $|fPosZ| < 10 \text{ cm}$.

# %%
# N_before = len(df)      # check value

# df = df[ ( (df['fPosZ'] > 10) | (df['fPosZ'] < -10) ) ]
# N_dca = len(df)
# print(f'Rejected data wrt start :  {N-N_dca} ----->  {(N-N_dca)/N*100:.3f} %' )
# print(f'Remaining data:            {N_dca}')

# %% [markdown]
# ## ETA
# We reject $|fEta| > 0.8$ as requested (I don't know why).

# %%
print("Minimum value ot Eta:", np.min (df['fEta']) )
print("Maximum value ot Eta:", np.max (df['fEta']) )
# Out:
# Minimum value ot Eta: -0.7999901
# Maximum value ot Eta: 0.79999137

# %% [markdown]
# All the values have already $|fEta| < 0.8$.

# %%
# N_before = len(df)      # check value

# df = df[ ( (df['fEta'] > 0.8) | (df['fEta'] < -0.8) ) ]
# N_dca = len(df)
# print(f'Rejected data wrt start :  {N-N_dca} ----->  {(N-N_dca)/N*100:.3f} %' )
# print(f'Remaining data:            {N_dca}')

# %% [markdown]
# ## PID
# Memo: each row of O2filtertrackextr is a single track (i.e. a single particle).

# %% [markdown]
# #### TPC
# Filtered for both:
# * $pi$ with charge $+1$ with TPC between -3 and +3 sigma.
# * $K$ with charge $-1$ with TPC between -3 and +3 sigma.
#
# Also added a filter for the pions curve in the NsigmaKa plot (see plot image).

# %%
N_before = len(df)      # check value
sigma_limit = 3         # threshold of sigma for the cut

df = df[ 
    ( (df['fNsigmaTPCpi'] > -sigma_limit) & (df['fNsigmaTPCpi'] < sigma_limit) & (df['fCharge'] == 1)  )    # selecting positive pions
    | # or
    ( (df['fNsigmaTPCka'] > -sigma_limit) & (df['fNsigmaTPCka'] < sigma_limit) & (df['fCharge'] == -1) )    # selecting negative kaons
    | # or
    ( (df['fPt'] > 0) & (df['fPt'] <1) & (df['fNsigmaTPCka'] > -15) & (df['fNsigmaTPCka'] < 0) & (df['fCharge'] == 1) ) # for including the pions curve in kaons plot
    ]
N_tpc = len(df)
print(f'Rejected data wrt start:  {N-N_tpc} ----->  {(N-N_tpc)/N*100:.3f} %' )
print(f'Remaining data:           {N_tpc}')
# Out:
# Rejected data wrt start:  612385 ----->  30.601 %
# Remaining data:           1388798

# %% [markdown]
# #### TOF
# Filtered for both:
# * $pi$ with charge $+1$ with TOF between -3 and +3 sigma.
# * $K$ with charge $-1$ with TOF between -3 and +3 sigma.
#
# Also added TOF values of -999 (meaning the information is missing).
# Also added a filter for the pions curve in the NsigmaKa plot (see plot image).

# %%
N_before = len(df)      # check value
sigma_limit = 3         # threshold of sigma for the cut

df = df[ 
    ( (df['fNsigmaTOFpi'] > -sigma_limit) & (df['fNsigmaTOFpi'] < sigma_limit) & (df['fCharge'] == 1) )     # selecting positive pions
    | # or
    ( (df['fNsigmaTOFka'] > -sigma_limit) & (df['fNsigmaTOFka'] < sigma_limit) & (df['fCharge'] == -1) )    # selecting negative kaons
    | # or
    ( (df['fNsigmaTOFka'].abs() >= 998.5) | (df['fNsigmaTOFpi'].abs() >= 998.5) )   # including missing info
    | # or
    ( (df['fPt'] > 0) & (df['fPt'] <3) & (df['fNsigmaTOFka'] > -50) & (df['fNsigmaTOFka'] < 0) & (df['fCharge'] == 1) ) # for including the pions curve in kaons plot
    ]
N_tof = len(df)
print(f'Rejected data wrt before:  {N_before-N_tof} ----->  {(N_before-N_tof)/N_before*100:.3f} %' )
print(f'Rejected data wrt start :  {N-N_tof} ----->  {(N-N_tof)/N*100:.3f} %' )
print(f'Remaining data:            {N_tof}')
# Out:
# Rejected data wrt before:  222282 ----->  16.005 %
# Rejected data wrt start :  834667 ----->  41.709 %
# Remaining data:            1166516

# %% [markdown]
# ---

# %% [markdown]
# ## SINGLE TRACK VARIABLES

# %% [markdown]
# #### dcaXY
# This variable for the background should be around 0, for the signal different from 0. So we cut the central values.

# %%
# ONLY PLOT CODE:
dca_xy = np.array( df['fDcaXY'] )

# filter:
dca_xy_filt = dca_xy[(dca_xy > -0.012) & (dca_xy < 0.012)]
fig,ax = plt.subplots(figsize=(13,4))
ax.hist(dca_xy_filt, bins=500)
plt.axvline(x=0, color='r', linestyle='--', label='x = 0')
plt.xticks( np.arange(-0.01, 0.01, 0.002) )
plt.show()

# %% [markdown]
# I don't see a clear cluster outside the one in the center. Let's try by heart, taking the tails:

# %%
# CUT CODE:
N_before = len(df)
df = df[ ( (df['fDcaXY'] > 0.0002) | (df['fDcaXY'] < -0.0002) ) ]
N_dca = len(df)
print(f'Rejected data wrt before:  {N_before-N_dca} ----->  {(N_before-N_dca)/N_before*100:.3f} %' )
print(f'Rejected data wrt start :  {N-N_dca} ----->  {(N-N_dca)/N*100:.3f} %' )
print(f'Remaining data:            {N_dca}')
# Out:
# Rejected data wrt before:  51267 ----->  4.395 %
# Rejected data wrt start :  885934 ----->  44.271 %
# Remaining data:            1115249

# %% [markdown]
# #### $p_t$

# %%
# ONLY PLOT CODE:
pt = np.array( df['fPt'] )

# plot
fig,ax = plt.subplots(figsize=(13,3))
pt_filt = pt[ pt<3 ]
ax.hist(pt_filt, bins=1000)
plt.xticks( np.arange(0, 3.1, 0.3) )
plt.show()

# %% [markdown]
# As for suggestion, we set $p_t > 0.3$ $GeV/c$.

# %%
# CUT CODE:
pt_filt = pt[ pt>0.3 ]

N_before = len(df)
df = df[ df['fPt'] > 0.3 ]
N_pt = len(df)
print(f'Rejected data wrt before:  {N_before-N_pt} ----->  {(N_before-N_pt)/N_before*100:.3f} %' )
print(f'Rejected data wrt start :  {N-N_pt} ----->  {(N-N_pt)/N*100:.3f} %' )
print(f'Remaining data:            {N_pt}')
# Out:
# Rejected data wrt before:  0 ----->  0.000 %
# Rejected data wrt start :  885934 ----->  44.271 %
# Remaining data:            1115249

# %% [markdown]
# This was expected because it was already filtered for this by the professor.

# %% [markdown]
# ---

# %% [markdown]
# # PAIR VARIABLES CUTS
# Let's search for couples of particles coming from the same collision (through "fIndexCollisions"), with opposite charge (for $K^-$ and $\pi^+$), and plot their $dcaXY \cdot dcaXY$ distribution.
#
# We do it creating a new dataframe where we save the index of each particle in the pair (in this way we have a connection with the original dataframe) and the product of dcaXY of the two particles.

# %%
# Particle masses in GeV
m_K = 0.493677
m_pi = 0.139570
m_d0 = 1.86484

# %% [markdown]
# #### INVARIANT MASS
# The general formula for the invariant mass $M$ of two particles is:
#
# $$
# M^2 = (E_1 + E_2)^2 - |\vec{p}_1 + \vec{p}_2|^2
# $$
#
# Expanding the momentum vector components: $ M^2 = (E_1 + E_2)^2 - (p_{x1} + p_{x2})^2 - (p_{y1} + p_{y2})^2 - (p_{z1} + p_{z2})^2 $
#
# This can also be written as: $ M = \sqrt{(E_1 + E_2)^2 - (\vec{p}_1 + \vec{p}_2)^2} $
#
# The energy $E_i$ of each particle is computed using the relativistic relation:
#
# $$
# E_i = \sqrt{|\vec{p}_i|^2 + m_i^2}
# $$
#
# In our detector data, we are given the transverse momentum $p_T$, the pseudorapidity $\eta$, and the azimuthal angle $\alpha$ (denoted as $fPt$, $fEta$, and $fAlpha$). We can compute the three components of momentum for each track using the following relations:
#
# $$
# p_x = p_T \cdot \cos(\alpha)
# $$
#
# $$
# p_y = p_T \cdot \sin(\alpha)
# $$
#
# $$
# p_z = p_T \cdot \sinh(\eta)
# $$
#
# Then, the full momentum magnitude is:
#
# $$
# |\vec{p}| = \sqrt{p_T^2 \cdot \cosh^2(\eta)} = p_T \cdot \cosh(\eta)
# $$
#
# So the energy of each particle becomes:
#
# $$
# E = \sqrt{(p_T \cdot \cosh(\eta))^2 + m^2}
# $$
#
# And we can compute the invariant mass in our case with:
# $$
# M^2 = (E_K + E_\pi)^2 - (p_{x,K} + p_{x,\pi})^2 - (p_{y,K} + p_{y,\pi})^2 - (p_{z,K} + p_{z,\pi})^2
# $$
#
# ---
# We can also use an approximated expression for the invariant mass, valid in the ultra-relativistic limit ($m \ll E$), where masses are neglected:
#
#
# $$
# M \approx \sqrt{2 \cdot p_{T1} \cdot p_{T2} \cdot \left( \cosh(\eta_1 - \eta_2) - \cos(\alpha_1 - \alpha_2) \right)}
# $$

# %%
# let's RESET the indexes of df:
df = df.reset_index(drop=True)
print("Now the dataframe has", len(df), "rows")
df
# Out:
# Now the dataframe has 1115249 rows
#               fPt      fEta  fCharge    fDcaXY  fNsigmaTPCpi  fNsigmaTPCka  \
# 0        0.311392  0.052986        1 -0.005521     -1.248399    -12.175531
# 1        0.884602 -0.032689       -1 -0.001190      0.343225     -1.040863
# 2        1.256379  0.315822       -1 -0.001517      0.124642      0.791008
# 3        0.394436 -0.480611        1  0.015037     -1.978565     -9.120785
# 4        1.416420 -0.431723       -1  0.003487      0.601058      1.920502
# ...           ...       ...      ...       ...           ...           ...
# 1115244  1.034499 -0.688490        1  0.006238      0.728543      1.295525
# 1115245  0.395956  0.285064        1  0.004453     -0.770692     -8.978865
# 1115246  1.500522 -0.478508       -1  0.000691     -0.508438      0.822282
# 1115247  0.484358 -0.429436        1  0.008038      0.048201     -5.711690
# 1115248  0.799283  0.581246       -1 -0.002887      0.222214     -0.635532
#
# ...

# %%
# let's initialize a list, then we will create a dataframe
pairs = []

# Iterate over each collision group
for collision_idx, group in df.groupby('fIndexCollisions'):

    # Only collisions with at least 2 tracks
    if len(group) < 2: continue

    # Reset index of the group to 0..N-1 and move original index in new column 'orig_index'
    group = group.reset_index().rename(columns={'index': 'orig_index'})

    # Iterate over all unique pairs of tracks
    for i1, i2 in combinations(range(len(group)), 2):
        row1 = group.iloc[i1]
        row2 = group.iloc[i2]

        # only pairs with opposite charge
        if row1['fCharge'] * row2['fCharge'] < 0:
            product_dcaXY = row1['fDcaXY'] * row2['fDcaXY']

            if row1['fCharge'] > 0: pos, neg = row1, row2
            else:                   pos, neg = row2, row1
            
            # INVARIANT MASS calculation
            pt1, pt2 = pos['fPt'], neg['fPt']
            eta1, eta2 = pos['fEta'], neg['fEta']
            phi1, phi2 = pos['fAlpha'], neg['fAlpha']
            delta_eta = eta1 - eta2
            delta_phi = phi1 - phi2

            # approximation formula
            inv_mass_approx = np.sqrt(2 * pt1 * pt2 * (np.cosh(delta_eta) - np.cos(delta_phi)))

            # exact formula:
            E1 = np.sqrt( (pt1*np.cosh(eta1))**2 + m_pi**2 )
            E2 = np.sqrt( (pt2*np.cosh(eta2))**2 + m_K**2 )
            px1 = pt1*np.cos(phi1)
            py1 = pt1*np.sin(phi1)
            pz1 = pt1*np.sinh(eta1)
            px2 = pt2*np.cos(phi2)
            py2 = pt2*np.sin(phi2)
            pz2 = pt2*np.sinh(eta2)
            inv_mass = np.sqrt( (E1+E2)**2 - (px1+px2)**2 - (py1+py2)**2 - (pz1+pz2)**2 )


            # total transverse momentum of the D0 candidate (used later for sliced plots)
            pt_total = np.sqrt((px1 + px2)**2 + (py1 + py2)**2)

            # let's add the found pairs to the list
            pairs.append({
                'collision_index': int(row1['fIndexCollisions']),
                'track1_index': int(row1['orig_index']),
                'track2_index': int(row2['orig_index']),
                'dcaXY_product': product_dcaXY,
                'inv_mass': inv_mass,
                'inv_mass_approx': inv_mass_approx,
                'pt': pt_total
            })


# create a dataframe with the result:
df_pairs = pd.DataFrame(pairs)

# %%
# df_pairs.to_csv('output_pairs.csv', index=False)

# %%
! ls -lh
# Out:
# total 174M
# -rw-rw-r-- 1 bsecco bsecco 162K Jul  2 14:57 find_D0.ipynb
# -rw-rw-r-- 1 bsecco bsecco 173M Jun 22 16:44 output_pairs.csv
# -rw-rw-r-- 1 bsecco bsecco  97K Jun 20 13:39 surfing_data.ipynb

# %% [markdown]
# #### DcaXY product PLOT

# %%
# Plot histogram
fig,ax = plt.subplots(2,1,figsize=(13,4))
ax[0].hist(df_pairs['dcaXY_product'], bins=300)
ax[0].set_ylabel("Counts")
ax[0].set_title("DCAxy product distribution (opposite charge pairs)")
# filter plot:
prod = df_pairs['dcaXY_product']
prod_filt = prod[ (prod>-0.00001) & (prod<0.00001) ]
ax[1].hist(prod_filt, bins=300)
ax[1].set_ylabel("Counts")
ax[1].set_xlabel("Product of DCAxy")


plt.show()

# %% [markdown]
# Il motivo del buco centrale è dovuto al cut iniziale sulla dcaXY, che taglia i valori vicini allo 0.

# %% [markdown]
# #### INAVARIANT MASS PLOT

# %%
pt_bins = [(0, 0.5), (0.5, 1), (1.5, 2), (2, 3), (3,100)]  # define your pt slices here

for pt_min, pt_max in pt_bins:
    df_slice = df_pairs[(df_pairs['pt'] >= pt_min) & (df_pairs['pt'] < pt_max)]
    val = df_slice["inv_mass"]

    fig, ax = plt.subplots(2, 1, figsize=(13, 4))
    fig.suptitle(f"Invariant Mass for {pt_min} < $p_T$ < {pt_max} GeV/c", fontsize=14)

    # full-range plot
    ax[0].hist(val[val < 4], bins=500)
    ax[0].axvline(x=m_d0, color='red', linestyle='--', linewidth=1.5, label='$D^0$ mass')
    ax[0].legend()
    ax[0].set_ylabel("Counts")

    # zoom-in plot
    zoom_val = val[(val > 1.8) & (val < 1.9)]
    ax[1].hist(zoom_val, bins=500)
    ax[1].axvline(x=m_d0, color='red', linestyle='--', linewidth=1.5, label='$D^0$ mass')
    ax[1].legend()
    ax[1].set_xlabel("Invariant Mass [$GeV/c^2$]")
    ax[1].set_ylabel("Counts")

    plt.tight_layout()
    plt.show()

# %%
# CODE FOR MONITORING RAM LIVE USAGE:
# run it in a different notebook from the one you are using
import psutil
import time
from IPython.display import clear_output

for _ in range(100):
    mem = psutil.virtual_memory()
    clear_output(wait=True)
    print(f"Used: {mem.used / 1e9:.2f} GB | Available: {mem.available / 1e9:.2f} GB")
    time.sleep(1)
# Out:
# Used: 2.05 GB | Available: 1.87 GB
